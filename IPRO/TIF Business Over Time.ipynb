# %% [markdown]
# ### SQL

# %%
df_14 = _deepnote_execute_sql('SELECT TIF_Name, count(*) as ct\nFROM \'/work/Business Info By Size/SmallBusinessInfo.csv\'\nGROUP BY TIF_Name\nORDER BY ct DESC', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_14
# Out:
#                                               TIF_Name      ct
# 0                                                   []  303048
# 1    ['Red and Purple Modernization Phase One Proje...   27409
# 2                         ['Red Line Extension (RLE)']   23326
# 3                                  ['LaSalle Central']   14675
# 4              ['Kinzie Industrial Conservation Area']   11970
# ..                                                 ...     ...
# 119                                    ['67th/Cicero']      13
# 120               ['Wilson Yard', 'Lawrence/Broadway']      10
# 121              ['Belmont/Central', 'Belmont/Cicero']       7
# 122  ['Western Avenue/Rock Island', '119th Street/I...       5
# 123  ['105th Street and Vincennes Avenue', '107th/H...       2
#
# [124 rows x 2 columns]

# %%
df_7 = _deepnote_execute_sql('SELECT DISTINCT LEGAL_NAME\nFROM \'/work/Business Info By Size/SmallBusinessInfo.csv\'', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_7
# Out:
#                            LEGAL_NAME
# 0                 JYM INVESTMENTS LLC
# 1             LEOPARDO COMPANIES INC.
# 2              ELIAS A. KANELLOPOULOS
# 3          Silverwolf Productions LLC
# 4                  DOMONANT MEDIA LLC
# ...                               ...
# 135081  Ezza Nails - 26 S Halsted LLC
# 135082                    AMEPOL INC.
# 135083                      AWA FOMBA
# 135084              TERRANCE J. WATTS
# 135085          UNIQUEPRINTZ69 L.L.C.
#
# [135086 rows x 1 columns]

# %%
small_business_start_end = _deepnote_execute_sql('SELECT LEGAL_NAME, SUBSTRING(TIF_Name, 3, LENGTH(TIF_Name) - 4) AS tif, MIN(LICENSE_TERM_START_DATE) AS start, MAX(LICENSE_TERM_EXPIRATION_DATE) AS end\nFROM \'/work/Business Info By Size/SmallBusinessInfo.csv\'\nGROUP BY LEGAL_NAME, TIF_Name', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
small_business_start_end
# Out:
#                         LEGAL_NAME                                  tif  \
# 0              JYM INVESTMENTS LLC                                   []
# 1          LEOPARDO COMPANIES INC.  Kinzie Industrial Conservation Area
# 2           ELIAS A. KANELLOPOULOS                                   []
# 3       Silverwolf Productions LLC                                   []
# 4               DOMONANT MEDIA LLC                         35th/Halsted
# ...                            ...                                  ...
# 148546                 AMEPOL INC.                                   []
# 148547                   AWA FOMBA                    119th Street/I-57
# 148548           TERRANCE J. WATTS    105th Street and Vincennes Avenue
# 148549             LEAD RESCUE NFP             Red Line Extension (RLE)
# 148550       UNIQUEPRINTZ69 L.L.C.                                   []
#
#             start        end
# 0      2020-12-17 2023-01-15
# 1      2006-05-11 2022-09-15
# ...

# %%
medium_business_start_end = _deepnote_execute_sql('SELECT LEGAL_NAME, SUBSTRING(TIF_Name, 3, LENGTH(TIF_Name) - 4) AS tif, MIN(LICENSE_TERM_START_DATE) AS start, MAX(LICENSE_TERM_EXPIRATION_DATE) AS end\nFROM \'/work/Business Info By Size/MediumBusinessInfo.csv\'\nGROUP BY LEGAL_NAME, TIF_Name', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
medium_business_start_end
# Out:
#                                           LEGAL_NAME  \
# 0                              1021 MONTROSE, L.L.C.
# 1      LINCOLN SQUARE RAVENSWOOD CHAMBER OF COMMERCE
# 2             BRIGHT HORIZONS CHILDREN'S CENTERS LLC
# 3                            COMPASS GROUP USA, INC.
# 4                     FOXTROT VENTURES, INCORPORATED
# ...                                              ...
# 11512                      WISHBONE RESTAURANT, INC.
# 11513                       THE BERGERAC GROUP, LTD.
# 11514          STERLING BAY PROPERTY MANAGEMENT, LLC
# 11515                          HANIG'S FOOTWEAR,INC.
# 11516                                     KA S. CHOI
#
#                                                   tif      start        end
# 0                                         Wilson Yard 2005-05-13 2024-06-15
# 1                                                  [] 2012-09-20 2023-02-26
# 2      Red and Purple Modernization Phase One Project 2014-05-13 2024-08-15
# ...

# %%
big_business_start_end = _deepnote_execute_sql('SELECT LEGAL_NAME, SUBSTRING(TIF_Name, 3, LENGTH(TIF_Name) - 4) AS tif, MIN(LICENSE_TERM_START_DATE) AS start, MAX(LICENSE_TERM_EXPIRATION_DATE) AS end\nFROM \'/work/Business Info By Size/BigBusinessInfo.csv\'\nGROUP BY LEGAL_NAME, TIF_Name', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
big_business_start_end
# Out:
#                                      LEGAL_NAME  \
# 0                         GRAHAM ENTERPRISE INC
# 1                      NAIL JUNKIE ROSCOE, INC.
# 2               CHICAGO CUBS BASEBALL CLUB, LLC
# 3                             HYATT CORPORATION
# 4                         GRAHAM ENTERPRISE INC
# ...                                         ...
# 25622                             FAR SOUTH CDC
# 25623                    NOVIBEL ENTERPRISE LLC
# 25624                    CRISTINA TARRIBA VILLA
# 25625                  AFM MATTRESS COMPANY LLC
# 25626  EL MORO DE LETRAN CHURROS & BAKERY CORP.
#
#                                                   tif      start        end
# 0                                                  [] 2010-04-08 2024-06-15
# 1                                                  [] 2016-07-12 2022-07-15
# 2      Red and Purple Modernization Phase One Project 2010-03-16 2024-06-15
# 3                                                  [] 2002-05-16 2024-09-15
# ...

# %%
small_start_end_with_tif_data = _deepnote_execute_sql('SELECT tifs.name, tifs.approval_d, small_businesses.LEGAL_NAME, small_businesses.start, small_businesses.end\nFROM \'/work/Boundaries TIF no geo.csv\' tifs\nJOIN small_business_start_end small_businesses\nON tifs.name = small_businesses.tif\nWHERE small_businesses.start IS NOT NULL OR small_businesses.end IS NOT NULL;\n', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
small_start_end_with_tif_data
# Out:
#                                       name approval_d  \
# 0      Kinzie Industrial Conservation Area 1998-06-10
# 1                             35th/Halsted 1997-01-14
# 2            Northwest Industrial Corridor 1998-12-02
# 3                      Fullerton/Milwaukee 2000-02-16
# 4                         Armitage/Pulaski 2007-06-13
# ...                                    ...        ...
# 72347             Red Line Extension (RLE) 2022-12-14
# 72348             Roseland/Michigan Avenue 2002-01-16
# 72349             Roseland/Michigan Avenue 2002-01-16
# 72350                        Touhy/Western 2006-09-13
# 72351             Roseland/Michigan Avenue 2002-01-16
#
#                            LEGAL_NAME      start        end
# 0             LEOPARDO COMPANIES INC. 2006-05-11 2022-09-15
# 1                  DOMONANT MEDIA LLC 2022-08-08 2024-08-15
# 2            PRIMERA IRON WORKS CORP. 2010-09-03 2024-09-15
# 3      FLYING SQUIRREL INDUSTRIES LLC 2014-05-08 2024-05-15
# ...

# %%
medium_start_end_with_tif_data = _deepnote_execute_sql('SELECT tifs.name, tifs.approval_d, medium_businesses.LEGAL_NAME, medium_businesses.start, medium_businesses.end\nFROM \'/work/Boundaries TIF no geo.csv\' tifs\nJOIN medium_business_start_end medium_businesses\nON tifs.name = medium_businesses.tif\nWHERE medium_businesses.start IS NOT NULL OR medium_businesses.end IS NOT NULL;\n', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
medium_start_end_with_tif_data
# Out:
#                                                 name approval_d  \
# 0                                        Wilson Yard 2001-06-27
# 1     Red and Purple Modernization Phase One Project 2016-11-30
# 2                           Red Line Extension (RLE) 2022-12-14
# 3     Red and Purple Modernization Phase One Project 2016-11-30
# 4                                            Midwest 2000-05-17
# ...                                              ...        ...
# 7253                                   Touhy/Western 2006-09-13
# 7254                             71st & Stony Island 1998-10-07
# 7255                             71st & Stony Island 1998-10-07
# 7256                             71st & Stony Island 1998-10-07
# 7257                             71st & Stony Island 1998-10-07
#
#                                   LEGAL_NAME      start        end
# 0                      1021 MONTROSE, L.L.C. 2005-05-13 2024-06-15
# ...

# %%
big_start_end_with_tif_data = _deepnote_execute_sql('SELECT tifs.name, tifs.approval_d, big_businesses.LEGAL_NAME, big_businesses.start, big_businesses.end\nFROM \'/work/Boundaries TIF no geo.csv\' tifs\nJOIN big_business_start_end big_businesses\nON tifs.name = big_businesses.tif\nWHERE big_businesses.start IS NOT NULL OR big_businesses.end IS NOT NULL;\n', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
big_start_end_with_tif_data
# Out:
#                                                  name approval_d  \
# 0      Red and Purple Modernization Phase One Project 2016-11-30
# 1      Red and Purple Modernization Phase One Project 2016-11-30
# 2                                      Archer/Western 2009-02-11
# 3                                Western Avenue North 2000-01-12
# 4                                        47th/Ashland 2002-03-27
# ...                                               ...        ...
# 14152                             71st & Stony Island 1998-10-07
# 14153                             71st & Stony Island 1998-10-07
# 14154                             71st & Stony Island 1998-10-07
# 14155                                   Touhy/Western 2006-09-13
# 14156                             71st & Stony Island 1998-10-07
#
#                             LEGAL_NAME      start        end
# 0      CHICAGO CUBS BASEBALL CLUB, LLC 2010-03-16 2024-06-15
# 1                GRAHAM ENTERPRISE INC 2009-04-21 2024-06-15
# ...

# %% [markdown]
# Number of businesses that went out of business after TIF creation

# %%
df_10 = _deepnote_execute_sql('SELECT COUNT(*) \nFROM small_start_end_with_tif_data data\nWHERE data.start <= data.approval_d AND data.end > data.approval_d', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_10
# Out:
#    count_star()
# 0          7799

# %%
df_9 = _deepnote_execute_sql('SELECT COUNT(*) \nFROM medium_start_end_with_tif_data data\nWHERE data.start <= data.approval_d AND data.end > data.approval_d', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_9
# Out:
#    count_star()
# 0          1771

# %%
df_8 = _deepnote_execute_sql('SELECT COUNT(*) \nFROM big_start_end_with_tif_data data\nWHERE data.start <= data.approval_d AND data.end > data.approval_d', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_8
# Out:
#    count_star()
# 0          1787

# %% [markdown]
# Percent of businesses that went out of business after TIF creation by district

# %%
small_business_ratios = _deepnote_execute_sql('SELECT data.name, COUNT(*) as count, COUNT(*) * 1.0 / total_count AS ratio\nFROM small_start_end_with_tif_data data\nJOIN (\n    SELECT name, COUNT(*) AS total_count\n    FROM small_start_end_with_tif_data\n    GROUP BY name\n) counts\nON counts.name = data.name\nWHERE data.start <= data.approval_d AND data.end > data.approval_d\nGROUP BY data.name, total_count\nORDER BY ratio DESC', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
small_business_ratios
# Out:
#                                                  name  count     ratio
# 0                               Diversey/Narragansett     33  0.440000
# 1                Elston/Armstrong Industrial Corridor     40  0.363636
# 2                                 Little Village East    124  0.321244
# 3                                     73rd/University     15  0.312500
# 4                                        Ewing Avenue    137  0.312073
# ..                                                ...    ...       ...
# 81                                       63rd/Pulaski      2  0.001601
# 82  Stony Island Avenue Commercial and Burnside In...      1  0.001538
# 83                                       35th/Halsted      1  0.001263
# 84                                             Pilsen      1  0.000802
# 85                                            Midwest      1  0.000563
#
# [86 rows x 3 columns]

# %%
medium_business_ratios = _deepnote_execute_sql('SELECT data.name, COUNT(*) as count, COUNT(*) * 1.0 / total_count AS ratio\nFROM medium_start_end_with_tif_data data\nJOIN (\n    SELECT name, COUNT(*) AS total_count\n    FROM medium_start_end_with_tif_data\n    GROUP BY name\n) counts\nON counts.name = data.name\nWHERE data.start <= data.approval_d AND data.end > data.approval_d\nGROUP BY data.name, total_count\nORDER BY ratio DESC', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
medium_business_ratios
# Out:
#                                              name  count     ratio
# 0   Pratt/Ridge Industrial Park Conservation Area      1  1.000000
# 1                          Diversey/Chicago River      1  1.000000
# 2                                    83rd/Stewart      7  0.875000
# 3                                Harrison/Central      6  0.857143
# 4                                      47th/State     14  0.777778
# ..                                            ...    ...       ...
# 64                                   Central West      1  0.015873
# 65                                    Wilson Yard      1  0.014925
# 66                                    53rd Street      1  0.012987
# 67                                        Midwest      1  0.008475
# 68                            Fullerton/Milwaukee      1  0.005025
#
# [69 rows x 3 columns]

# %%
big_business_ratios = _deepnote_execute_sql('SELECT data.name, COUNT(*) as count, COUNT(*) * 1.0 / total_count AS ratio\nFROM big_start_end_with_tif_data data\nJOIN (\n    SELECT name, COUNT(*) AS total_count\n    FROM big_start_end_with_tif_data\n    GROUP BY name\n) counts\nON counts.name = data.name\nWHERE data.start <= data.approval_d AND data.end > data.approval_d\nGROUP BY data.name, total_count\nORDER BY ratio DESC', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
big_business_ratios
# Out:
#                                               name  count     ratio
# 0                                   116th/Avenue O      3  0.750000
# 1                                   Randolph/Wells     18  0.391304
# 2                                26th & King Drive      3  0.375000
# 3                       Western Avenue/Rock Island     47  0.358779
# 4                               Stevenson/Brighton     44  0.349206
# 5                                   Archer/Western     66  0.343750
# 6                                     Ewing Avenue     35  0.343137
# 7                                  73rd/University      3  0.333333
# 8               Little Village Industrial Corridor      6  0.333333
# 9                                 Armitage/Pulaski     22  0.333333
# 10                                   Addison South     24  0.328767
# 11  Red and Purple Modernization Phase One Project    370  0.316510
# 12                                        Avondale     18  0.315789
# ...

# %%
df_15 = _deepnote_execute_sql('SELECT name, approval_d\nFROM \'/work/Boundaries TIF no geo.csv\'\nWHERE approval_d = (\n    SELECT MIN(approval_d)\n    FROM \'/work/Boundaries TIF no geo.csv\'\n);', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_15
# Out:
#               name approval_d
# 0  Michigan/Cermak 1989-09-13

# %% [markdown]
# ### Python

# %%
# !pip install geopy
# !pip install geopandas
# !pip install numpy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.cm import get_cmap
import json
from geopy.geocoders import Nominatim
import geopandas as gpd
from shapely.geometry import Point
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 19.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 9.3 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
small_start_end_with_tif_data = pd.DataFrame(small_start_end_with_tif_data)
medium_start_end_with_tif_data = pd.DataFrame(medium_start_end_with_tif_data)
big_start_end_with_tif_data = pd.DataFrame(big_start_end_with_tif_data)

small_start_end_with_tif_data.to_csv('/work/Business_Info_With_TIF_Info/small_businesses.csv', index=False)
medium_start_end_with_tif_data.to_csv('/work/Business_Info_With_TIF_Info/medium_businesses.csv', index=False)
big_start_end_with_tif_data.to_csv('/work/Business_Info_With_TIF_Info/big_businesses.csv', index=False)

# %%
tif_geo = gpd.read_file('/work/Boundaries TIF.geojson')[['name', 'geometry']]
frame = gpd.read_file('BoundariesCommunity.geojson')

tif_geo
# Out:
#                            name  \
# 0                116th/Avenue O
# 1            Bryn Mawr/Broadway
# 2            51st and Lake Park
# 3                     Lakefront
# 4                  Madden/Wells
# ..                          ...
# 116              Lincoln Avenue
# 117                63rd/Pulaski
# 118  Cortland and Chicago River
# 119              Canal/Congress
# 120     Madison/Austin Corridor
#
#                                               geometry
# 0    MULTIPOLYGON (((-87.53995 41.68459, -87.53995 ...
# 1    MULTIPOLYGON (((-87.66051 41.98451, -87.66037 ...
# 2    MULTIPOLYGON (((-87.58854 41.80155, -87.58902 ...
# 3    MULTIPOLYGON (((-87.59624 41.81693, -87.59676 ...
# 4    MULTIPOLYGON (((-87.61454 41.82808, -87.61455 ...
# ..                                                 ...
# 116  MULTIPOLYGON (((-87.71047 41.99673, -87.71047 ...
# 117  MULTIPOLYGON (((-87.72180 41.76583, -87.72186 ...
# 118  MULTIPOLYGON (((-87.66612 41.92000, -87.66603 ...
# ...

# %%
small_business_ratios_with_geometry = tif_geo.merge(small_business_ratios, on='name')
fig, ax = plt.subplots(figsize=(10, 10))
frame.plot(ax=ax, alpha=.2, facecolor='grey')
small_business_ratios_with_geometry.plot(column='ratio', cmap='OrRd', legend=True, ax=ax)
plt.show()

# %%
medium_business_ratios_with_geometry = tif_geo.merge(medium_business_ratios, on='name')
fig, ax = plt.subplots(figsize=(10, 10))
frame.plot(ax=ax, alpha=.2, facecolor='grey')
medium_business_ratios_with_geometry.plot(column='ratio', cmap='OrRd', legend=True, ax=ax)
plt.show()

# %%
big_business_ratios_with_geometry = tif_geo.merge(big_business_ratios, on='name')
fig, ax = plt.subplots(figsize=(10, 10))
frame.plot(ax=ax, alpha=.2, facecolor='grey')
big_business_ratios_with_geometry.plot(column='ratio', cmap='OrRd', legend=True, ax=ax)
plt.show()

# %%
small_business_ratios_with_geometry
# Out:
#                                                  name  \
# 0                                      116th/Avenue O
# 1                                        Madden/Wells
# 2                                         Ohio/Wabash
# 3   Stony Island Avenue Commercial and Burnside In...
# 4                                         Wilson Yard
# ..                                                ...
# 81                 Little Village Industrial Corridor
# 82     Red and Purple Modernization Phase One Project
# 83                                  119th Street/I-57
# 84                                       63rd/Pulaski
# 85                         Cortland and Chicago River
#
#                                              geometry  count     ratio
# 0   MULTIPOLYGON (((-87.53995 41.68459, -87.53995 ...      1  0.166667
# 1   MULTIPOLYGON (((-87.61454 41.82808, -87.61455 ...      1  0.038462
# 2   MULTIPOLYGON (((-87.62823 41.89337, -87.62799 ...      1  0.034483
# ...

# %% [markdown]
# ### Businesses By Year Per Tif

# %%
small_start_end_with_tif_data[small_start_end_with_tif_data['name'] == '35th/Halsted']['approval_d'].iloc[0].year
small_start_end_with_tif_data['start']
# Out:
# 0       2006-05-11
# 1       2022-08-08
# 2       2010-09-03
# 3       2014-05-08
# 4       2019-09-13
#            ...
# 72347   2017-11-29
# 72348   2023-01-17
# 72349   2023-02-15
# 72350   2010-02-01
# 72351   2017-04-17
# Name: start, Length: 72352, dtype: datetime64[us]

# %%
def plot_active_businesses_by_year(tif_name, colors=['blue', 'green', 'red'], smallOriginalDf=small_start_end_with_tif_data, mediumOriginalDf=medium_start_end_with_tif_data, bigOriginalDf=big_start_end_with_tif_data):
    

    # process the earliest start and latest end year for small businesses
    smallDf = smallOriginalDf[smallOriginalDf['name'] == tif_name]
    smallDf.loc[:, 'start_year'] = smallDf['start'].dt.year
    smallDf.loc[:, 'end_year'] = smallDf['end'].dt.year
    earliest_small_year = smallDf['start_year'].min()

    # process the earliest start and latest end year for medium businesses
    mediumDf = mediumOriginalDf[mediumOriginalDf['name'] == tif_name]
    mediumDf.loc[:, 'start_year'] = mediumDf['start'].dt.year
    mediumDf.loc[:, 'end_year'] = mediumDf['end'].dt.year
    earliest_medium_year = mediumDf['start_year'].min()

    # process the earliest start and latest end year for big businesses
    bigDf = bigOriginalDf[bigOriginalDf['name'] == tif_name]
    bigDf.loc[:, 'start_year'] = bigDf['start'].dt.year
    bigDf.loc[:, 'end_year'] = bigDf['end'].dt.year
    earliest_big_year = bigDf['start_year'].min()
    
    
    tif_approval_date = smallDf['approval_d'].iloc[0].year

    years = range(int(min(earliest_small_year, earliest_medium_year, earliest_big_year)), 2024, 1)

    small_business_active_counts = []
    medium_business_active_counts = []
    big_business_active_counts = []

    for year in years:
        small_business_active_counts.append(((smallDf['start_year'] <= year) & (smallDf['end_year'] >= year)).sum())
        medium_business_active_counts.append(((mediumDf['start_year'] <= year) & (mediumDf['end_year'] >= year)).sum())
        big_business_active_counts.append(((bigDf['start_year'] <= year) & (bigDf['end_year'] >= year)).sum())

    print("------------------------")
    print(small_business_active_counts)
    print(medium_business_active_counts)
    print(big_business_active_counts)

    print("------------------------")

    fig, ax = plt.subplots(figsize=(40, 20))
    bar_width = 0.25

    # Adjust the positions for each category
    years_shifted = np.arange(len(years))
    years_shifted_small = years_shifted - bar_width
    years_shifted_medium = years_shifted
    years_shifted_big = years_shifted + bar_width

    # Plotting the bars
    plt.bar(years_shifted_small, small_business_active_counts, width=bar_width, color=colors[0], label='No Chain')
    plt.bar(years_shifted_medium, medium_business_active_counts, width=bar_width, color=colors[1], label='Local Chain')
    plt.bar(years_shifted_big, big_business_active_counts, width=bar_width, color=colors[2], label='National Chain')

    # Additional plot settings
    if tif_approval_date in list(years):
        plt.axvline(x=list(years).index(tif_approval_date) + .5, color='red', linestyle='--', linewidth=3.0)  # Just as an example, adjust as needed
    plt.xlabel('Year')
    plt.ylabel('Number of Active Businesses in ')
    plt.title('Number of Active Businesses Each Year in ' + tif_name)
    plt.xticks(years_shifted, years)
    plt.legend(fontsize='large')
    plt.show()
    
    



plot_active_businesses_by_year('Washington Park')
# Out:
# /tmp/ipykernel_122/947833457.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smallDf.loc[:, 'start_year'] = smallDf['start'].dt.year
# /tmp/ipykernel_122/947833457.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smallDf.loc[:, 'end_year'] = smallDf['end'].dt.year
# /tmp/ipykernel_122/947833457.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=41bd1eeb-8ade-41a5-ae81-cf4a88f38197' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
