# %%
# !pip install geopy==2.4.1
# !pip install geodatasets==2023.12.0
from geopy.geocoders import Nominatim
import geopandas as gpd
import pandas as pd
import geodatasets
import matplotlib.pyplot as plt
from shapely.geometry import Point
import json
# Out:
# Collecting geopy==2.4.1
#   Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 20.8 MB/s eta 0:00:00
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 12.6 MB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Collecting geodatasets==2023.12.0
#   Downloading geodatasets-2023.12.0-py3-none-any.whl (19 kB)
# Collecting pooch
#   Downloading pooch-1.8.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 17.8 MB/s eta 0:00:00
# Collecting platformdirs>=2.5.0
#   Downloading platformdirs-4.2.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pooch->geodatasets==2023.12.0) (21.3)
# Requirement already satisfied: requests>=2.19.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pooch->geodatasets==2023.12.0) (2.28.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=20.0->pooch->geodatasets==2023.12.0) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.19.0->pooch->geodatasets==2023.12.0) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.19.0->pooch->geodatasets==2023.12.0) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.19.0->pooch->geodatasets==2023.12.0) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.19.0->pooch->geodatasets==2023.12.0) (3.4)
# Installing collected packages: platformdirs, pooch, geodatasets
# Successfully installed geodatasets-2023.12.0 platformdirs-4.2.0 pooch-1.8.1
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# calling the Nominatim tool and create Nominatim class
loc = Nominatim(user_agent="Geopy Library")

def getLongAlt(address):
    getLoc = loc.geocode(address)
    return getLoc.latitude, getLoc.longitude

# %%
# This cell from Alattin Kirtisoglu
tif = gpd.read_file('/work/chiTifBoundaries.shp')
# Set the coordinate reference system to the standard latitude/longitude system
tif = tif.set_crs(epsg=4326)

tif.plot()
# tif.shape
# len(tif)
# Out:
# <AxesSubplot: >

# %%
tif_geo = gpd.read_file('Boundaries TIF.geojson')
# Set the coordinate reference system to the standard latitude/longitude system
tif_geo = tif_geo.set_crs(epsg=4326)

tif_geo.plot()
# tif.shape
# len(tif)
# Out:
# <AxesSubplot: >

# %%
tif.iloc[[114]].plot()
# Out:
# <AxesSubplot: >

# %%
tif_geo.iloc[[115]]
# tif_geo.iloc[[115]].plot()
# Out:
#     sbif               name     shape_area show objectid_1          name_trim  \
# 115    Y  119th Street/I-57  52679426.8904    0        119  119th Street/I-57
#
#     wards_2023    ref approval_d objectid  ...     shape_leng comm_area  \
# 115      19,21  T-125  11/6/2002     5235  ...  48809.1889126     53,75
#
#     objectid_2                                               use repealed_d  \
# 115        119  Mixed-use:  Commercial/Residential/Institutional       None
#
#          type     shape_le_1        ind  expiration  \
# 115  Existing  48809.1889126  Mixed-use  12/31/2026
#
#                                               geometry
# 115  MULTIPOLYGON (((-87.65446 41.69868, -87.65458 ...
#
# [1 rows x 21 columns]

# %%
def isInsideTIF(point):
    # takes a Point class and returns the index of the TIF that contains the Point
    # NOTE: RETURNS AN ARRAY NOT BOOL
    returnArray = []
    # iterate over all the distrcits and see if it contains the given point
    for index, row in tif.iterrows():
        if row['geometry'].contains(point):
            returnArray.append(index)
    
    return returnArray

# %%
def isInsideTIF_Geo(point):# Point(long, lat)
    # takes a Point class and returns the index of the TIF that contains the Point
    # NOTE: RETURNS AN ARRAY NOT BOOL
    returnArray = []
    # iterate over all the distrcits and see if it contains the given point
    for index, row in tif_geo.iterrows():
        if row['geometry'].contains(point):
            # returnArray.append(index)
            returnArray.append(row['name'])
    
    return returnArray

# long, lat
print(isInsideTIF_Geo(Point(-87.65454023,41.68421355)))
# Out:
# ['119th Street/I-57']

# %%
tif_geo
# Out:
#     sbif                        name     shape_area show objectid_1  \
# 0      N              116th/Avenue O  11512032.0441    1          1
# 1      Y          Bryn Mawr/Broadway  1497351.76204    1          2
# 2      N          51st and Lake Park  99810.7553475    1          3
# 3      N                   Lakefront  1234864.43789    2          4
# 4      N                Madden/Wells  5460412.60763    2          5
# ..   ...                         ...            ...  ...        ...
# 116    Y              Lincoln Avenue  7596571.99264    1        120
# 117    Y                63rd/Pulaski  9238352.82417    1        121
# 118    N  Cortland and Chicago River  7631475.18575    0        122
# 119    N              Canal/Congress  3048664.30904    1        123
# 120    Y     Madison/Austin Corridor  17180566.5443    1        124
#
#                       name_trim wards_2023    ref  approval_d objectid  ...  \
# 0                116th/Avenue O         10  T-182  10/31/2018     5167  ...
# 1            Bryn Mawr/Broadway         48  T- 13   11/4/1998     5207  ...
# 2            51st and Lake Park          4  T-175  11/15/2012     5185  ...
# 3                     Lakefront          4  T-119   3/27/2002     5150  ...
# 4                  Madden/Wells          4  T-126   11/6/2002        0  ...
# ..                          ...        ...    ...         ...      ...  ...
# 116              Lincoln Avenue      40,50  T- 77   11/3/1999     5242  ...
# 117                63rd/Pulaski      13,23  T- 98   5/17/2000     5243  ...
# 118  Cortland and Chicago River       2,32  T-183   4/10/2019     5246  ...
# 119              Canal/Congress   28,34,42  T- 63  11/12/1998     5249  ...
# 120     Madison/Austin Corridor   28,29,37  T- 75   9/29/1999     5176  ...
#
#         shape_leng    comm_area objectid_2  \
# 0    22113.6634385     51,52,55        100
# 1    10146.7645744           77         38
# 2    1319.69144432           41         19
# 3    7017.57899731           36         34
# 4    12134.5933039     35,36,38        129
# ..             ...          ...        ...
# 116  31074.4029002       2,4,13        120
# 117  56569.2043874  57,62,64,65        121
# 118  17249.9092933    7,8,22,24        122
# 119   15935.144818           28        123
# 120   87527.053734     25,26,27        125
#
#                                                   use repealed_d      type  \
# 0    Mixed-use: Comm/Indust/Institut/Parks/Open Space       None  Existing
# 1                  Mixed-use:  Residential/Commercial       None  Existing
# 2           Mixed-use:  Residential/Commercial/Retail       None  Existing
# 3                                         Residential       None  Existing
# 4                                         Residential       None  Existing
# ..                                                ...        ...       ...
# 116  Mixed-use:  Residential/Commercial/Institutional       None  Existing
# 117                  Mixed-use:  See Plan for Details       None  Existing
# 118      Mixed-use:  Res/Comm/Instit/Parks/Open Space       None  Existing
# 119  Mixed-use:  Residential/Commercial/Institutional       None  Existing
# 120  Mixed-use:  Residential/Commercial/Institutional       None  Existing
#
#         shape_le_1          ind  expiration  \
# 0    22113.6634385    Mixed-use  12/31/2042
# 1    10146.7645744    Mixed-use  12/31/2032
# 2    1319.69144432    Mixed-use  12/31/2036
# 3    7017.57899731  Residential  12/31/2026
# 4    12134.5933039  Residential  12/31/2038
# ..             ...          ...         ...
# 116  31074.4029002    Mixed-use  12/31/2035
# 117  56569.2043874    Mixed-use  12/31/2024
# 118  17249.9092933    Mixed-use  12/31/2043
# 119   15935.144818    Mixed-use  12/31/2034
# 120   87527.053734    Mixed-use  12/31/2035
#
#                                               geometry
# 0    MULTIPOLYGON (((-87.53995 41.68459, -87.53995 ...
# 1    MULTIPOLYGON (((-87.66051 41.98451, -87.66037 ...
# 2    MULTIPOLYGON (((-87.58854 41.80155, -87.58902 ...
# 3    MULTIPOLYGON (((-87.59624 41.81693, -87.59676 ...
# 4    MULTIPOLYGON (((-87.61454 41.82808, -87.61455 ...
# ..                                                 ...
# 116  MULTIPOLYGON (((-87.71047 41.99673, -87.71047 ...
# 117  MULTIPOLYGON (((-87.72180 41.76583, -87.72186 ...
# 118  MULTIPOLYGON (((-87.66612 41.92000, -87.66603 ...
# 119  MULTIPOLYGON (((-87.64485 41.88255, -87.64474 ...
# 120  MULTIPOLYGON (((-87.76715 41.89150, -87.76715 ...
#
# [121 rows x 21 columns]

# %%
tif_no_geo = df.iloc[:, :-1]
# Out:
#     sbif                        name     shape_area show objectid_1  \
# 0      N              116th/Avenue O  11512032.0441    1          1
# 1      Y          Bryn Mawr/Broadway  1497351.76204    1          2
# 2      N          51st and Lake Park  99810.7553475    1          3
# 3      N                   Lakefront  1234864.43789    2          4
# 4      N                Madden/Wells  5460412.60763    2          5
# ..   ...                         ...            ...  ...        ...
# 116    Y              Lincoln Avenue  7596571.99264    1        120
# 117    Y                63rd/Pulaski  9238352.82417    1        121
# 118    N  Cortland and Chicago River  7631475.18575    0        122
# 119    N              Canal/Congress  3048664.30904    1        123
# 120    Y     Madison/Austin Corridor  17180566.5443    1        124
#
#                       name_trim wards_2023    ref  approval_d objectid fid_1  \
# 0                116th/Avenue O         10  T-182  10/31/2018     5167   100
# 1            Bryn Mawr/Broadway         48  T- 13   11/4/1998     5207    38
# 2            51st and Lake Park          4  T-175  11/15/2012     5185    18
# 3                     Lakefront          4  T-119   3/27/2002     5150    34
# 4                  Madden/Wells          4  T-126   11/6/2002        0    85
# ..                          ...        ...    ...         ...      ...   ...
# 116              Lincoln Avenue      40,50  T- 77   11/3/1999     5242   119
# 117                63rd/Pulaski      13,23  T- 98   5/17/2000     5243   120
# 118  Cortland and Chicago River       2,32  T-183   4/10/2019     5246   121
# 119              Canal/Congress   28,34,42  T- 63  11/12/1998     5249   122
# 120     Madison/Austin Corridor   28,29,37  T- 75   9/29/1999     5176   123
#
#         shape_leng    comm_area objectid_2  \
# 0    22113.6634385     51,52,55        100
# 1    10146.7645744           77         38
# 2    1319.69144432           41         19
# 3    7017.57899731           36         34
# 4    12134.5933039     35,36,38        129
# ..             ...          ...        ...
# 116  31074.4029002       2,4,13        120
# 117  56569.2043874  57,62,64,65        121
# 118  17249.9092933    7,8,22,24        122
# 119   15935.144818           28        123
# 120   87527.053734     25,26,27        125
#
#                                                   use repealed_d      type  \
# 0    Mixed-use: Comm/Indust/Institut/Parks/Open Space       None  Existing
# 1                  Mixed-use:  Residential/Commercial       None  Existing
# 2           Mixed-use:  Residential/Commercial/Retail       None  Existing
# 3                                         Residential       None  Existing
# 4                                         Residential       None  Existing
# ..                                                ...        ...       ...
# 116  Mixed-use:  Residential/Commercial/Institutional       None  Existing
# 117                  Mixed-use:  See Plan for Details       None  Existing
# 118      Mixed-use:  Res/Comm/Instit/Parks/Open Space       None  Existing
# 119  Mixed-use:  Residential/Commercial/Institutional       None  Existing
# 120  Mixed-use:  Residential/Commercial/Institutional       None  Existing
#
#         shape_le_1          ind  expiration
# 0    22113.6634385    Mixed-use  12/31/2042
# 1    10146.7645744    Mixed-use  12/31/2032
# 2    1319.69144432    Mixed-use  12/31/2036
# 3    7017.57899731  Residential  12/31/2026
# 4    12134.5933039  Residential  12/31/2038
# ..             ...          ...         ...
# 116  31074.4029002    Mixed-use  12/31/2035
# 117  56569.2043874    Mixed-use  12/31/2024
# 118  17249.9092933    Mixed-use  12/31/2043
# 119   15935.144818    Mixed-use  12/31/2034
# 120   87527.053734    Mixed-use  12/31/2035
#
# [121 rows x 20 columns]

# %%
tif_no_geo.to_csv("Boundaries TIF no geo.csv")

# %%
df_2 = _deepnote_execute_sql('SELECT MIN(approval_d) AS min_date, MAX(approval_d) AS max_date,MIN(expiration) AS min_date_exp, MAX(expiration) AS max_date_exp\nFROM \'Boundaries TIF no geo.csv\';\n', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_2
# Out:
#     min_date   max_date min_date_exp max_date_exp
# 0 1989-09-13 2022-12-14   2024-12-31   2058-12-31

# %%
df_3 = _deepnote_execute_sql('SELECT MAX(approval_d) AS min_date\nFROM \'Boundaries TIF no geo.csv\';\n', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_3
# Out:
#     min_date
# 0 2022-12-14

# %% [markdown]
# ----------------------------------------------------------------Mapping shapes to names---------------------------------------------------------

# %%
df_1 = _deepnote_execute_sql('-- SELECT id, MIN(long) as long, MIN(lat) as lat\nSELECT id, long, lat\nFROM \'TIF_2021_shapefile.csv\'\n-- where id = \'105th Street and Vincennes Avenue\'\n-- GROUP BY id;', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled')
df_1
# Out:
#                                       id       long        lat
# 0      105th Street and Vincennes Avenue -87.651471  41.717617
# 1      105th Street and Vincennes Avenue -87.651429  41.717614
# 2      105th Street and Vincennes Avenue -87.650856  41.717621
# 3      105th Street and Vincennes Avenue -87.650701  41.717623
# 4      105th Street and Vincennes Avenue -87.650551  41.717625
# ...                                  ...        ...        ...
# 96925                           Woodlawn -87.590389  41.784624
# 96926                           Woodlawn -87.590383  41.784628
# 96927                           Woodlawn -87.590307  41.784586
# 96928                           Woodlawn -87.590233  41.784543
# 96929                           Woodlawn -87.590229  41.784377
#
# [96930 rows x 3 columns]

# %%
len(tif)
tif.iloc[[1]].plot()
# Out:
# <AxesSubplot: >

# %%
print(isInsideTIF(Point(-87.65454023,41.68421355)))
# Out:
# [114]

# %%
vals_dict = {}
# i = 0
for index, row in df_1.iterrows():
    lst = isInsideTIF(Point(row['long'],row['lat']))
    for i in range(len(lst)):
        if row['id'] not in vals_dict.keys():
            vals_dict[row['id']] = {lst[i]:1,}
        else:
            if lst[i] not in vals_dict[row['id']].keys():
                vals_dict[row['id']][lst[i]] = 1
            else:
                vals_dict[row['id']][lst[i]] += 1

    # if i == 5000:
    #     break
    # i+=1
print(vals_dict)

file_path = 'my_dict.json'

# Serialize the dictionary to a JSON-formatted string
json_string = json.dumps(vals_dict, indent=2)

# Write the JSON string to a file
with open(file_path, 'w') as file:
    file.write(json_string)
# Out:
# {'105th Street and Vincennes Avenue': {17: 93, 120: 3, 61: 8, 114: 2}, '107th/Halsted': {114: 33, 61: 133, 17: 25, 120: 39, 42: 22}, '111th Street/Kedzie Avenue Business District': {76: 199, 1: 3}, '116th/Avenue O': {46: 432, 3: 15, 4: 323}, '119th and Halsted': {42: 210, 61: 23, 120: 7, 114: 85}, '119th Street/I-57': {114: 377, 61: 22, 42: 81, 1: 95, 17: 1}, '24th/Michigan': {127: 175, 68: 50, 130: 44, 13: 16, 126: 10}, '26th & King Drive': {10: 64, 13: 20, 130: 32}, '35th & Wallace': {84: 196, 130: 203, 91: 10}, '35th/Halsted': {91: 562, 84: 1, 119: 18}, '35th/State': {5: 131, 130: 35, 13: 86, 84: 2}, '43rd Street/Cottage Grove Avenue': {100: 28, 2: 186, 108: 49}, '47th and King Drive': {108: 234, 13: 40, 2: 66, 104: 3, 23: 34, 58: 1}, '47th/Ashland': {117: 660, 8: 3, 58: 9, 22: 4}, '47th/Halsted': {58: 784, 108: 1, 23: 17, 104: 1, 98: 22, 117: 16, 8: 32, 13: 2}, '47th/State': {23: 127, 108: 54, 104: 59, 58: 12}, '51st and Lake Park': {64: 15, 109: 9}, '51st/Archer': {90: 671, 122: 28, 40: 9, 18: 100}, '53rd Street': {64: 13, 109: 185}, '63rd/Ashland': {22: 405, 98: 12, 35: 3, 117: 1}, '63rd/Pulaski': {122: 744, 115: 4, 21: 1, 63: 4, 90: 17}, '67th and Wentworth': {35: 306, 57: 28, 34: 14, 28: 49, 22: 2, 98: 28, 104: 17}, '67th/Cicero': {21: 199, 115: 198}, '71st & Stony Island': {105: 27, 51: 1197, 70: 3, 34: 7}, '73rd/University': {34: 5, 27: 88}, '79th and Cicero': {33: 250}, '79th Street Corridor': {41: 411, 28: 31, 65: 2, 106: 3}, '79th Street/Southwest Highway': {65: 1159, 106: 392, 41: 1}, '79th/Vincennes': {28: 359, 35: 57, 41: 24}, '83rd/Stewart': {99: 71}, '87th/Cottage Grove': {35: 11, 34: 778, 27: 3, 51: 10, 81: 17}, '95th & Western': {14: 133, 1: 7}, 'Addison South': {73: 17, 48: 240, 52: 2}, 'Archer Courts': {54: 36, 130: 56, 16: 1}, 'Archer/Central': {63: 787, 40: 2, 122: 1, 21: 2, 50: 2}, 'Archer/Western': {119: 358, 16: 9, 91: 25, 18: 4}, 'Armitage Pulaski': {113: 91, 124: 21, 38: 1}, 'Austin Commercial': {78: 805, 38: 6, 55: 12}, 'Avalon Park/South Shore': {70: 302, 51: 8}, 'Avondale': {97: 197, 107: 20, 0: 7}, 'Belmont/Central': {62: 4, 9: 1235, 111: 17, 38: 10, 12: 13, 11: 23}, 'Belmont/Cicero': {111: 288, 38: 1, 9: 14, 0: 2}, 'Bronzeville': {13: 307, 130: 38, 108: 38, 5: 82, 10: 18}, 'Bryn Mawr/Broadway': {86: 106, 101: 14, 96: 46}, 'Canal/Congress': {128: 169, 103: 9, 126: 1, 77: 2}, 'Central West': {19: 633, 87: 56, 116: 70}, 'Chicago/Central Park': {112: 518, 66: 119, 116: 71, 87: 91, 38: 125, 124: 18}, 'Chicago/Kingsbury': {59: 48, 6: 172}, 'Cicero/Archer': {40: 14, 50: 222, 63: 2, 129: 3}, 'Cicero/Stevenson': {40: 25, 129: 94, 50: 4}, 'Clark Street & Ridge Avenue': {30: 249, 44: 14, 96: 53, 24: 23, 53: 2}, 'Clark/Montrose': {96: 75, 94: 161, 89: 1}, 'Commercial Avenue': {25: 874, 83: 70, 4: 88}, 'Cortland and Chicago River': {125: 115, 96: 34, 39: 49}, 'Devon & Western': {53: 292, 36: 3, 30: 3, 89: 2, 121: 2, 26: 1}, 'Devon/Sheridan': {44: 190, 96: 45, 30: 11}, 'Diversey/Chicago River': {48: 2, 52: 21}, 'Diversey/Narragansett': {9: 28, 11: 143, 12: 2}, 'Division/Homan': {66: 382, 67: 34, 116: 25, 112: 109, 124: 2}, 'Edgewater/Ashland': {30: 22, 24: 70}, 'Elston/Armstrong Industrial Corridor': {93: 199}, 'Englewood Mall Area': {69: 137, 98: 131}, 'Englewood Neighborhood': {98: 570, 58: 25, 104: 153, 35: 60, 22: 11, 69: 136}, 'Ewing Avenue': {3: 109, 46: 4, 4: 46}, 'Foster and California': {82: 32, 121: 1}, 'Foster/Edens': {79: 7, 72: 221}, 'Fullerton/Milwaukee': {97: 19, 107: 854, 124: 1}, 'Galewood/Armitage Industrial': {12: 507, 38: 30, 118: 5, 9: 37}, 'Goose Island': {92: 150, 39: 107}, 'Greater Southwest Industrial (East)': {106: 666, 41: 1, 65: 386}, 'Greater Southwest Industrial (West)': {122: 5, 115: 665, 21: 190}, 'Harrison/Central': {55: 70, 47: 129, 87: 47, 95: 6}, 'Hollywood/Sheridan': {96: 241, 101: 290, 43: 4, 86: 15}, 'Homan-Arthington': {87: 121, 123: 180}, 'Humboldt Park Commercial': {66: 38, 67: 378, 124: 3}, 'Jefferson Park Business District': {110: 189}, 'Jefferson/Roosevelt': {77: ...

# %%
# now need to pick max from each and make the csv to save
# Read the dictionary back from the file
file_path = 'my_dict.json'
with open(file_path, 'r') as file:
    vals_dict = json.load(file)

print("Loaded dictionary:", vals_dict)

reverse_dict = {}

for tif_name in vals_dict.keys():
    nums_dict = vals_dict[tif_name]
    # for num in nums_dict.keys():
    max_key = max(nums_dict, key=lambda k: nums_dict[k])
    vals_dict[tif_name] = int(max_key)
    reverse_dict[int(max_key)] = tif_name
    
    print(tif_name,":",int(max_key))

print(vals_dict)
print(reverse_dict)

# write the reverse_dict
file_path = 'tif_num_names.json'

json_string = json.dumps(reverse_dict, indent=2)

with open(file_path, 'w') as file:
    file.write(json_string)

# write the vals_dict
file_path = 'tif_names_num.json'

json_string = json.dumps(vals_dict, indent=2)

with open(file_path, 'w') as file:
    file.write(json_string)
# Out:
# Loaded dictionary: {'105th Street and Vincennes Avenue': {'17': 93, '120': 3, '61': 8, '114': 2}, '107th/Halsted': {'114': 33, '61': 133, '17': 25, '120': 39, '42': 22}, '111th Street/Kedzie Avenue Business District': {'76': 199, '1': 3}, '116th/Avenue O': {'46': 432, '3': 15, '4': 323}, '119th and Halsted': {'42': 210, '61': 23, '120': 7, '114': 85}, '119th Street/I-57': {'114': 377, '61': 22, '42': 81, '1': 95, '17': 1}, '24th/Michigan': {'127': 175, '68': 50, '130': 44, '13': 16, '126': 10}, '26th & King Drive': {'10': 64, '13': 20, '130': 32}, '35th & Wallace': {'84': 196, '130': 203, '91': 10}, '35th/Halsted': {'91': 562, '84': 1, '119': 18}, '35th/State': {'5': 131, '130': 35, '13': 86, '84': 2}, '43rd Street/Cottage Grove Avenue': {'100': 28, '2': 186, '108': 49}, '47th and King Drive': {'108': 234, '13': 40, '2': 66, '104': 3, '23': 34, '58': 1}, '47th/Ashland': {'117': 660, '8': 3, '58': 9, '22': 4}, '47th/Halsted': {'58': 784, '108': 1, '23': 17, '104': 1, '98': 22, '117': 16, '8': 32, '13': 2}, '47th/State': {'23': 127, '108': 54, '104': 59, '58': 12}, '51st and Lake Park': {'64': 15, '109': 9}, '51st/Archer': {'90': 671, '122': 28, '40': 9, '18': 100}, '53rd Street': {'64': 13, '109': 185}, '63rd/Ashland': {'22': 405, '98': 12, '35': 3, '117': 1}, '63rd/Pulaski': {'122': 744, '115': 4, '21': 1, '63': 4, '90': 17}, '67th and Wentworth': {'35': 306, '57': 28, '34': 14, '28': 49, '22': 2, '98': 28, '104': 17}, '67th/Cicero': {'21': 199, '115': 198}, '71st & Stony Island': {'105': 27, '51': 1197, '70': 3, '34': 7}, '73rd/University': {'34': 5, '27': 88}, '79th and Cicero': {'33': 250}, '79th Street Corridor': {'41': 411, '28': 31, '65': 2, '106': 3}, '79th Street/Southwest Highway': {'65': 1159, '106': 392, '41': 1}, '79th/Vincennes': {'28': 359, '35': 57, '41': 24}, '83rd/Stewart': {'99': 71}, '87th/Cottage Grove': {'35': 11, '34': 778, '27': 3, '51': 10, '81': 17}, '95th & Western': {'14': 133, '1': 7}, 'Addison South': {'73': 17, '48': 240, '52': 2}, 'Archer Courts': {'54': 36, '130': 56, '16': 1}, 'Archer/Central': {'63': 787, '40': 2, '122': 1, '21': 2, '50': 2}, 'Archer/Western': {'119': 358, '16': 9, '91': 25, '18': 4}, 'Armitage Pulaski': {'113': 91, '124': 21, '38': 1}, 'Austin Commercial': {'78': 805, '38': 6, '55': 12}, 'Avalon Park/South Shore': {'70': 302, '51': 8}, 'Avondale': {'97': 197, '107': 20, '0': 7}, 'Belmont/Central': {'62': 4, '9': 1235, '111': 17, '38': 10, '12': 13, '11': 23}, 'Belmont/Cicero': {'111': 288, '38': 1, '9': 14, '0': 2}, 'Bronzeville': {'13': 307, '130': 38, '108': 38, '5': 82, '10': 18}, 'Bryn Mawr/Broadway': {'86': 106, '101': 14, '96': 46}, 'Canal/Congress': {'128': 169, '103': 9, '126': 1, '77': 2}, 'Central West': {'19': 633, '87': 56, '116': 70}, 'Chicago/Central Park': {'112': 518, '66': 119, '116': 71, '87': 91, '38': 125, '124': 18}, 'Chicago/Kingsbury': {'59': 48, '6': 172}, 'Cicero/Archer': {'40': 14, '50': 222, '63': 2, '129': 3}, 'Cicero/Stevenson': {'40': 25, '129': 94, '50': 4}, 'Clark Street & Ridge Avenue': {'30': 249, '44': 14, '96': 53, '24': 23, '53': 2}, 'Clark/Montrose': {'96': 75, '94': 161, '89': 1}, 'Commercial Avenue': {'25': 874, '83': 70, '4': 88}, 'Cortland and Chicago River': {'125': 115, '96': 34, '39': 49}, 'Devon & Western': {'53': 292, '36': 3, '30': 3, '89': 2, '121': 2, '26': 1}, 'Devon/Sheridan': {'44': 190, '96': 45, '30': 11}, 'Diversey/Chicago River': {'48': 2, '52': 21}, 'Diversey/Narragansett': {'9': 28, '11': 143, '12': 2}, 'Division/Homan': {'66': 382, '67': 34, '116': 25, '112': 109, '124': 2}, 'Edgewater/Ashland': {'30': 22, '24': 70}, 'Elston/Armstrong Industrial Corridor': {'93': 199}, 'Englewood Mall Area': {'69': 137, '98': 131}, 'Englewood Neighborhood': {'98': 570, '58': 25, '104': 153, '35': 60, '22': 11, '69': 136}, 'Ewing Avenue': {'3': 109, '46': 4, '4': 46}, 'Foster and California': {'82': 32, '121': 1}, 'Foster/Edens': {'79': 7, '72': 221}, 'Fullerton/Milwaukee': {'97': 19, '107': 854, '124': 1}, 'Galewood/Armitage Industri ...
# 105th Street and Vincennes Avenue : 17
# 107th/Halsted : 61
# 111th Street/Kedzie Avenue Business District : 76
# 116th/Avenue O : 46
# 119th and Halsted : 42
# 119th Street/I-57 : 114
# 24th/Michigan : 127
# 26th & King Drive : 10
# 35th & Wallace : 130
# 35th/Halsted : 91
# 35th/State : 5
# 43rd Street/Cottage Grove Avenue : 2
# 47th and King Drive : 108
# 47th/Ashland : 117
# 47th/Halsted : 58
# 47th/State : 23
# 51st and Lake Park : 64
# 51st/Archer : 90
# 53rd Street : 109
# 63rd/Ashland : 22
# 63rd/Pulaski : 122
# 67th and Wentworth : 35
# 67th/Cicero : 21
# 71st & Stony Island : 51
# 73rd/University : 27
# 79th and Cicero : 33
# 79th Street Corridor : 41
# 79th Street/Southwest Highway : 65
# 79th/Vincennes : 28
# 83rd/Stewart : 99
# 87th/Cottage Grove : 34
# 95th & Western : 14
# Addison South : 48
# Archer Courts : 130
# Archer/Central : 63
# Archer/Western : 119
# Armitage Pulaski : 113
# Austin Commercial : 78
# Avalon Park/South Shore : 70
# Avondale : 97
# Belmont/Central : 9
# Belmont/Cicero : 111
# Bronzeville : 13
# Bryn Mawr/Broadway : 86
# Canal/Congress : 128
# Central West : 19
# Chicago/Central Park : 112
# Chicago/Kingsbury : 6
# Cicero/Archer : 50
# Cicero/Stevenson : 129
# Clark Street & Ridge Avenue : 30
# Clark/Montrose : 94
# Commercial Avenue : 25
# Cortland and Chicago River : 125
# Devon & Western : 53
# Devon/Sheridan : 44
# Diversey/Chicago River : 52
# Diversey/Narragansett : 11
# Division/Homan : 66
# Edgewater/Ashland : 24
# Elston/Armstrong Industrial Corridor : 93
# Englewood Mall Area : 69
# Englewood Neighborhood : 98
# Ewing Avenue : 3
# Foster and California : 82
# Foster/Edens : 72
# Fullerton/Milwaukee : 107
# Galewood/Armitage Industrial : 12
# Goose Island : 92
# Greater Southwest Industrial (East) : 106
# Greater Southwest Industrial (West) : 115
# Harrison/Central : 47
# Hollywood/Sheridan : 101
# Homan-Arthington : 123
# Humboldt Park Commercial : 67
# Jefferson Park Business District : 110
# Jefferson/Roosevelt : 77
# Kennedy/Kimball : 60
# Kinzie Industrial Conservation Area : 116
# Lake Calumet Area Industrial : 4
# Lakefront : 29
# LaSalle Central : 103
# Lawrence/Broadway : 43
# Lawrence/Kedzie : 88
# Lawrence/Pulaski : 79
# Lincoln Avenue : 121
# Little Village East : 56
# Little Village Industrial Corridor : 80
# Madden/Wells : 100
# Madison/Austin Corridor : 55
# Michigan/Cermak : 68
# Midway Industrial Corridor : 40
# Midwest : 87
# Montclare : 118
# Montrose/Clarendon : 20
# Near North : 59
# North Branch (South) : 39
# North Pullman : 75
# Northwest Industrial Corridor : 38
# Ogden/Pulaski : 37
# Ohio/Wabash : 32
# Peterson/Cicero : 49
# Peterson/Pulaski : 31
# Pilsen : 16
# Portage Park : 0
# Pratt/Ridge Industrial Park Conservation Area : 36
# Pulaski Corridor : 124
# Randolph/Wells : 7
# Red and Purple Modernization Phase One Project : 96
# River West : 15
# Roosevelt/Cicero : 95
# Roosevelt/Clark : 130
# Roosevelt/Racine : 45
# Roosevelt/Union : 71
# Roseland/Michigan Avenue : 120
# Sanitary Drainage and Ship Canal : 74
# South Chicago : 83
# Stevenson/Brighton : 18
# Stockyards Southeast Quadrant Industrial : 8
# Stony Island Avenue Commercial and Burnside Industrial Corridors : 81
# Touhy/Western : 26
# Washington Park : 104
# West Irving Park : 62
# West Woodlawn : 57
# Western Avenue North : 89
# Western Avenue South : 73
# Western Avenue/Rock Island : 1
# Western/Ogden : 85
# Wilson Yard : 102
# Woodlawn : 105
# {'105th Street and Vincennes Avenue': 17, '107th/Halsted': 61, '111th Street/Kedzie Avenue Business District': 76, '116th/Avenue O': 46, '119th and Halsted': 42, '119th Street/I-57': 114, '24th/Michigan': 127, '26th & King Drive': 10, '35th & Wallace': 130, '35th/Halsted': 91, '35th/State': 5, '43rd Street/Cottage Grove Avenue': 2, '47th and King Drive': 108, '47th/Ashland': 117, '47th/Halsted': 58, '47th/State': 23, '51st and Lake Park': 64, '51st/Archer': 90, '53rd Street': 109, '63rd/Ashland': 22, '63rd/Pulaski': 122, '67th and Wentworth': 35, '67th/Cicero': 21, '71st & Stony Island': 51, '73rd/University': 27, '79th and Cicero': 33, '79th Street Corridor': 41, '79th Street/Southwest Highway': 65, '79th/Vincennes': 28, '83rd/Stewart': 99, '87th/Cottage Grove': 34, '95th & Western': 14, 'Addison South': 48, 'Archer Courts': 130, 'Archer/Central': 63, 'Archer/Western': 119, 'Armitage Pulaski': 113, 'Austin Commercial': 78, 'Avalon Park/South Shore': 70, 'Avondale': 97, 'Belmont/Central': 9, 'Belmont/Cicero': 111, 'Bronzeville': 13, 'Bryn Mawr/Broadway': 86, 'Canal/Congress': 128, 'Central West': 19, 'Chicago/Central Park': 112, 'Chicago/Kingsbury': 6, 'Cicero/Archer': 50, 'Cicero/Stevenson': 129, 'Clark Street & Ridge Avenue': 30, 'Clark/Montrose': 94, 'Commercial Avenue': 25, 'Cortland and Chicago River': 125, 'Devon & Western': 53, 'Devon/Sheridan': 44, 'Diversey/Chicago River': 52, 'Diversey/Narragansett': 11, 'Division/Homan': 66, 'Edgewater/Ashland': 24, 'Elston/Armstrong Industrial Corridor': 93, 'Englewood Mall Area': 69, 'Englewood Neighborhood': 98, 'Ewing Avenue': 3, 'Foster and California': 82, 'Foster/Edens': 72, 'Fullerton/Milwaukee': 107, 'Galewood/Armitage Industrial': 12, 'Goose Island': 92, 'Greater Southwest Industrial (East)': 106, 'Greater Southwest Industrial (West)': 115, 'Harrison/Central': 47, 'Hollywood/Sheridan': 101, 'Homan-Arthington': 123, 'Humboldt Park Commercial': 67, 'Jefferson Park Business District': 110, 'Jefferson/Roosevelt': 77, 'Kennedy/Kimball': 60, 'Kinzie Industrial Conservation Area': 116, 'Lake Calumet Area Industrial': 4, 'Lakefront': 29, 'LaSalle Central': 103, 'Lawrence/Broadway': 43, 'Lawrence/Kedzie': 88, 'Lawrence/Pulaski': 79, 'Lincoln Avenue': 121, 'Little Village East': 56, 'Little Village Industrial Corridor': 80, 'Madden/Wells': 100, 'Madison/Austin Corridor': 55, 'Michigan/Cermak': 68, 'Midway Industrial Corridor': 40, 'Midwest': 87, 'Montclare': 118, 'Montrose/Clarendon': 20, 'Near North': 59, 'North Branch (South)': 39, 'North Pullman': 75, 'Northwest Industrial Corridor': 38, 'Ogden/Pulaski': 37, 'Ohio/Wabash': 32, 'Peterson/Cicero': 49, 'Peterson/Pulaski': 31, 'Pilsen': 16, 'Portage Park': 0, 'Pratt/Ridge Industrial Park Conservation Area': 36, 'Pulaski Corridor': 124, 'Randolph/Wells': 7, 'Red and Purple Modernization Phase One Project': 96, 'River West': 15, 'Roosevelt/Cicero': 95, 'Roosevelt/Clark': 130, 'Roosevelt/Racine': 45, 'Roosevelt/Union': 71, 'Roseland/Michigan Avenue': 120, 'Sanitary Drainage and Ship Canal': 74, 'South Chicago': 83, 'Stevenson/Brighton': 18, 'Stockyards Southeast Quadrant Industrial': 8, 'Stony Island Avenue Commercial and Burnside Industrial Corridors': 81, 'Touhy/Western': 26, 'Washington Park': 104, 'West Irving Park': 62, 'West Woodlawn': 57, 'Western Avenue North': 89, 'Western Avenue South': 73, 'Western Avenue/Rock Island': 1, 'Western/Ogden': 85, 'Wilson Yard': 102, 'Woodlawn': 105}
# {17: '105th Street and Vincennes Avenue', 61: '107th/Halsted', 76: '111th Street/Kedzie Avenue Business District', 46: '116th/Avenue O', 42: '119th and Halsted', 114: '119th Street/I-57', 127: '24th/Michigan', 10: '26th & King Drive', 130: 'Roosevelt/Clark', 91: '35th/Halsted', 5: '35th/State', 2: '43rd Street/Cottage Grove Avenue', 108: '47th and King Drive', 117: '47th/Ashland', 58: '47th/Halsted', 23: '47th/State', 64: '51st and Lake Park', 90: '51st/Archer', 109: '53rd Street', 22: '63rd/Ashland', 122: '63rd/Pulaski', 35: '67th and Wentworth', 21: '67th/Cicero', 51: '71st & Stony Island', 27: '73rd/University', 33: '79th and Cicero', 41: '79th Street Corridor', 65: '79th Street/Southwest Highway', 28: '79th/Vincennes', 99: '83rd/Stewart', 34: '87th/Cottage Grove', 14: '95th & Western', 48: 'Addison South', 63: 'Archer/Central', 119: 'Archer/Western', 113: 'Armitage Pulaski', 78: 'Austin Commercial', 70: 'Avalon Park/South Shore', 97: 'Avondale', 9: 'Belmont/Central', 111: 'Belmont/Cicero', 13: 'Bronzeville', 86: 'Bryn Mawr/Broadway', 128: 'Canal/Congress', 19: 'Central West', 112: 'Chicago/Central Park', 6: 'Chicago/Kingsbury', 50: 'Cicero/Archer', 129: 'Cicero/Stevenson', 30: 'Clark Street & Ridge Avenue', 94: 'Clark/Montrose', 25: 'Commercial Avenue', 125: 'Cortland and Chicago River', 53: 'Devon & Western', 44: 'Devon/Sheridan', 52: 'Diversey/Chicago River', 11: 'Diversey/Narragansett', 66: 'Division/Homan', 24: 'Edgewater/Ashland', 93: 'Elston/Armstrong Industrial Corridor', 69: 'Englewood Mall Area', 98: 'Englewood Neighborhood', 3: 'Ewing Avenue', 82: 'Foster and California', 72: 'Foster/Edens', 107: 'Fullerton/Milwaukee', 12: 'Galewood/Armitage Industrial', 92: 'Goose Island', 106: 'Greater Southwest Industrial (East)', 115: 'Greater Southwest Industrial (West)', 47: 'Harrison/Central', 101: 'Hollywood/Sheridan', 123: 'Homan-Arthington', 67: 'Humboldt Park Commercial', 110: 'Jefferson Park Business District', 77: 'Jefferson/Roosevelt', 60: 'Kennedy/Kimball', 116: 'Kinzie Industrial Conservation Area', 4: 'Lake Calumet Area Industrial', 29: 'Lakefront', 103: 'LaSalle Central', 43: 'Lawrence/Broadway', 88: 'Lawrence/Kedzie', 79: 'Lawrence/Pulaski', 121: 'Lincoln Avenue', 56: 'Little Village East', 80: 'Little Village Industrial Corridor', 100: 'Madden/Wells', 55: 'Madison/Austin Corridor', 68: 'Michigan/Cermak', 40: 'Midway Industrial Corridor', 87: 'Midwest', 118: 'Montclare', 20: 'Montrose/Clarendon', 59: 'Near North', 39: 'North Branch (South)', 75: 'North Pullman', 38: 'Northwest Industrial Corridor', 37: 'Ogden/Pulaski', 32: 'Ohio/Wabash', 49: 'Peterson/Cicero', 31: 'Peterson/Pulaski', 16: 'Pilsen', 0: 'Portage Park', 36: 'Pratt/Ridge Industrial Park Conservation Area', 124: 'Pulaski Corridor', 7: 'Randolph/Wells', 96: 'Red and Purple Modernization Phase One Project', 15: 'River West', 95: 'Roosevelt/Cicero', 45: 'Roosevelt/Racine', 71: 'Roosevelt/Union', 120: 'Roseland/Michigan Avenue', 74: 'Sanitary Drainage and Ship Canal', 83: 'South Chicago', 18: 'Stevenson/Brighton', 8: 'Stockyards Southeast Quadrant Industrial', 81: 'Stony Island Avenue Commercial and Burnside Industrial Corridors', 26: 'Touhy/Western', 104: 'Washington Park', 62: 'West Irving Park', 57: 'West Woodlawn', 89: 'Western Avenue North', 73: 'Western Avenue South', 1: 'Western Avenue/Rock Island', 85: 'Western/Ogden', 102: 'Wilson Yard', 105: 'Woodlawn'}

# %% [markdown]
# -----------------------------------------------------------End mapping code----------------------------------------------------------------------

# %%
tif_geo.iloc[0]
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/dtypes/inference.py:397: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/dtypes/inference.py:398: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/io/formats/printing.py:115: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/io/formats/printing.py:119: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/io/formats/printing.py:123: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
# sbif                                                          N
# name                                             116th/Avenue O
# shape_area                                        11512032.0441
# show                                                          1
# objectid_1                                                    1
# name_trim                                        116th/Avenue O
# wards_2023                                                   10
# ref                                                       T-182
# approval_d                                           10/31/2018
# objectid                                                   5167
# fid_1                                                       100
# shape_leng                                        22113.6634385
# comm_area                                              51,52,55
# objectid_2                                                  100
# use            Mixed-use: Comm/Indust/Institut/Parks/Open Space
# repealed_d                                                 None
# type                                                   Existing
# shape_le_1                                        22113.6634385
# ind                                                   Mixed-use
# expiration                                           12/31/2042
# geometry      (POLYGON ((-87.53995487824876 41.6845889961506...
# Name: 0, dtype: object

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=41bd1eeb-8ade-41a5-ae81-cf4a88f38197' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
